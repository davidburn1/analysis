# %%
# %matplotlib inline  
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append('../../')
from msgAnalysis.src.poms import plotWaveguideAlignmentScans

plt.rcParams.update({'font.size':14, 'xtick.top':True, 'ytick.right':True, 'xtick.direction':'in', 'ytick.direction':'in'})

# %%
directory="./example_data/poms_waveguide_alignment"

# %%
df = pd.read_csv(directory+'/poms_waveguide_alignment.dat')

# %%
for i in range(len(df))[::-1]:
    plotWaveguideAlignmentScans(directory, df.iloc[i])
